# %% [markdown]
# # 01 — Resume data processing
#
# Prepare the downloaded resume dataset for fine-tuning. This stage will handle file discovery, text extraction, normalization, schema validation, deduplication, and train/validation/test splits.
#
# **Input:** `.data/`
#
# **Output:** `.data/processed/`

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.utils import DATA_DIR, PROCESSED_DATA_DIR, ensure_data_directories

ensure_data_directories()
print(f"Input directory: {DATA_DIR}")
print(f"Output directory: {PROCESSED_DATA_DIR}")

# %% [markdown]
# ## Processing plan
#
# 1. Discover the downloaded files.
# 2. Extract and normalize resume text.
# 3. Convert records to the model's input/output schema.
# 4. Remove unusable records and exact duplicates.
# 5. Create reproducible train, validation, and test splits.
# 6. Save the processed dataset and a data-quality summary.

# %%
# TODO: implement dataset discovery and file inventory.
# TODO: implement PDF/text extraction and normalization.
# TODO: define and validate the structured resume schema.
# TODO: deduplicate records and create deterministic splits.
# TODO: save processed artifacts under PROCESSED_DATA_DIR.
