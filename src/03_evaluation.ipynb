# %% [markdown]
# # 03 — Resume parser evaluation
#
# Test the fine-tuned model against held-out resume examples and measure extraction quality, robustness, latency, and resource usage.
#
# **Input:** `.data/processed/` and `.data/models/`
#
# **Output:** `.data/evaluation/`

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.utils import EVALUATION_DIR, MODELS_DIR, PROCESSED_DATA_DIR, ensure_data_directories

ensure_data_directories()
print(f"Evaluation data: {PROCESSED_DATA_DIR}")
print(f"Model directory: {MODELS_DIR}")
print(f"Results directory: {EVALUATION_DIR}")

# %% [markdown]
# ## Evaluation plan
#
# 1. Load the best fine-tuned checkpoint.
# 2. Run inference on the held-out test set.
# 3. Calculate field-level precision, recall, and F1.
# 4. Measure parsing latency and resource usage.
# 5. Analyze failures by section, layout, and document quality.
# 6. Save reproducible metrics and example predictions.

# %%
# TODO: load the fine-tuned model and held-out test records.
# TODO: run inference and normalize predictions.
# TODO: calculate field-level and record-level metrics.
# TODO: benchmark latency and resource usage.
# TODO: save metrics, failure analysis, and sample predictions to EVALUATION_DIR.
