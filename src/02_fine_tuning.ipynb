# %% [markdown]
# # 02 — Resume parser fine-tuning
#
# Fine-tune the selected small language model on the processed resume dataset.
#
# **Input:** `.data/processed/`
#
# **Output:** `.data/models/`

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.utils import MODELS_DIR, PROCESSED_DATA_DIR, ensure_data_directories

ensure_data_directories()
print(f"Training data: {PROCESSED_DATA_DIR}")
print(f"Model output: {MODELS_DIR}")

# %% [markdown]
# ## Training plan
#
# 1. Select and configure the base small language model.
# 2. Load the processed dataset and tokenizer.
# 3. Configure efficient training, checkpointing, and reproducibility.
# 4. Fine-tune on the resume parsing task.
# 5. Save the best checkpoint and training metadata.

# %%
# TODO: set the base model and tokenizer.
# TODO: load and tokenize the processed dataset.
# TODO: configure the training arguments and evaluation strategy.
# TODO: run fine-tuning and save the best model to MODELS_DIR.
# TODO: persist configuration, metrics, and the model revision.
